# %% [markdown]
# <a href="https://colab.research.google.com/github/Eason0227/Turbofan-Engine-Remaining-Useful-Life-Prediction/blob/main/DL_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NASA Turbofan Jet Engine DataSet - RUL prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import warnings
warnings.filterwarnings('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYCARET_CUSTOM_LOGGING_LEVEL'] = 'CRITICAL'

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf

from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import  LSTM,Input, Dense, AdditiveAttention, Concatenate

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735921138.157569    3957 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735921138.160994    3957 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def process_targets(data_length, early_rul):
  early_rul_duration = data_length - early_rul 
  if early_rul_duration <= 0: 
    return np.arange(data_length-1, -1, -1)
  else:
    new_early_rul = early_rul * np.ones(early_rul_duration) 
    origin_rul = np.arange(early_rul-1, -1, -1)
    return np.append(new_early_rul,origin_rul)
  

def process_input_data_with_targets(input_data, target_data , window_length , shift ):
  num_batches = np.int32(np.floor((len(input_data) - window_length)/shift)) + 1
  num_features = input_data.shape[1] 
  output = np.repeat(np.nan, repeats = num_batches * window_length * num_features)
  output_data = output.reshape(num_batches, window_length , num_features)

  if target_data is None: 
    for batch in range(num_batches):
      output_data[batch,:,:] = input_data[(0+shift*batch):(0+shift*batch+window_length),:]
    return output_data
  else :
    output_targets = np.repeat(np.nan, repeats = num_batches) 
    for batch in range(num_batches):
      window_start = shift * batch
      window_end = window_start + window_length

      output_data[batch,:,:] = input_data[window_start:window_end,:]
      output_targets[batch] = target_data[window_end-1]
    return output_data, output_targets
  

def process_test_data(test_data_for_an_engine, window_length, shift, num_test_windows = 1):

    max_num_test_batches = np.int32(np.floor((len(test_data_for_an_engine) - window_length)/shift)) + 1 

    if max_num_test_batches < num_test_windows:
        required_len = (max_num_test_batches -1)* shift + window_length
        batched_test_data_for_an_engine = process_input_data_with_targets(test_data_for_an_engine[-required_len:, :],
                                          target_data = None,
                                          window_length = window_length, shift = shift)
        return batched_test_data_for_an_engine, max_num_test_batches
    else:
        required_len = (num_test_windows - 1) * shift + window_length
        batched_test_data_for_an_engine = process_input_data_with_targets(test_data_for_an_engine[-required_len:, :],
                                          target_data = None,
                                          window_length = window_length, shift = shift)
        return batched_test_data_for_an_engine, num_test_windows

# %%
train_data = pd.read_csv("data/train_FD003.txt", sep= "\s+", header = None)
test_data = pd.read_csv("data/test_FD003.txt", sep = "\s+", header = None)
true_rul = pd.read_csv("data/RUL_FD003.txt", sep = '\s+', header = None)

# %%
window_length = 30
shift = 1
early_rul = 125      
processed_train_data = []
processed_train_targets = []

# How many test windows to take for each engine. If set to 1 (this is the default), only last window of test data for 
# each engine is taken. If set to a different number, that many windows from last are taken. 
# Final output is the average output of all windows.
num_test_windows = 1     
processed_test_data = []
num_test_windows_list = []

columns_to_be_dropped = [0,1,2,3,4,5,9,10,14,20,22,23]
#columns_to_be_dropped = [0,1,2,3,4,14,19,20]
#columns_to_be_dropped = [0,1,2,3,4,5,9,10,14,19,20,22,23]
#columns_to_be_dropped = [0,1,2,3,4,14,19,20]




train_data_first_column = train_data[0]
test_data_first_column = test_data[0]

# Scale data for all engines
#scaler = StandardScaler()
scaler = MinMaxScaler()
train_data = scaler.fit_transform(train_data.drop(columns = columns_to_be_dropped))
test_data = scaler.transform(test_data.drop(columns = columns_to_be_dropped))

train_data = pd.DataFrame(data = np.c_[train_data_first_column, train_data])
test_data = pd.DataFrame(data = np.c_[test_data_first_column, test_data])

num_train_machines = len(train_data[0].unique())
num_test_machines = len(test_data[0].unique())

# Process training and test data separately as number of engines in training and test set may be different.
# As we are doing scaling for full dataset, we are not bothered by different number of engines in training and test set.

# Process training data
for i in np.arange(1, num_train_machines + 1):
    temp_train_data = train_data[train_data[0] == i].drop(columns = [0]).values
    
    # Verify if data of given window length can be extracted from training data
    if (len(temp_train_data) < window_length):
        print("Train engine {} doesn't have enough data for window_length of {}".format(i, window_length))
        raise AssertionError("Window length is larger than number of data points for some engines. "
                             "Try decreasing window length.")
        
    temp_train_targets = process_targets(data_length = temp_train_data.shape[0], early_rul = early_rul)
    data_for_a_machine, targets_for_a_machine = process_input_data_with_targets(temp_train_data, temp_train_targets, 
                                                                                window_length = window_length, shift = shift)
    
    processed_train_data.append(data_for_a_machine)
    processed_train_targets.append(targets_for_a_machine)

processed_train_data = np.concatenate(processed_train_data)
processed_train_targets = np.concatenate(processed_train_targets)

# Process test data
for i in np.arange(1, num_test_machines + 1):
    temp_test_data = test_data[test_data[0] == i].drop(columns = [0]).values
    
    # Verify if data of given window length can be extracted from test data
    if (len(temp_test_data) < window_length):
        print("Test engine {} doesn't have enough data for window_length of {}".format(i, window_length))
        raise AssertionError("Window length is larger than number of data points for some engines. "
                             "Try decreasing window length.")
    
    # Prepare test data
    test_data_for_an_engine, num_windows = process_test_data(temp_test_data, window_length = window_length, shift = shift,
                                                             num_test_windows = num_test_windows)
    
    processed_test_data.append(test_data_for_an_engine)
    num_test_windows_list.append(num_windows)

processed_test_data = np.concatenate(processed_test_data)
true_rul = true_rul[0].values

# Shuffle training data
index = np.random.permutation(len(processed_train_targets))
processed_train_data, processed_train_targets = processed_train_data[index], processed_train_targets[index]

print("Processed training data shape: ", processed_train_data.shape)
print("Processed training rul shape: ", processed_train_targets.shape)
print("Processed test data shape: ", processed_test_data.shape)
print("True RUL shape: ", true_rul.shape)
# Out:
# Processed training data shape:  (21820, 30, 14)
# Processed training rul shape:  (21820,)
# Processed test data shape:  (100, 30, 14)
# True RUL shape:  (100,)

# %%
'''processed_train_data, processed_val_data, processed_train_targets, processed_val_targets = train_test_split(processed_train_data,
                                                        processed_train_targets,
                                                        test_size = 0.2,
                                                        random_state = 666)
print("Processed train data shape: ", processed_train_data.shape)
print("Processed validation data shape: ", processed_val_data.shape)
print("Processed train targets shape: ", processed_train_targets.shape)
print("Processed validation targets shape: ", processed_val_targets.shape)'''
# Out:
# 'processed_train_data, processed_val_data, processed_train_targets, processed_val_targets = train_test_split(processed_train_data,\n                                                        processed_train_targets,\n                                                        test_size = 0.2,\n                                                        random_state = 666)\nprint("Processed train data shape: ", processed_train_data.shape)\nprint("Processed validation data shape: ", processed_val_data.shape)\nprint("Processed train targets shape: ", processed_train_targets.shape)\nprint("Processed validation targets shape: ", processed_val_targets.shape)'

# %% [markdown]
# ## Attention-LSTM

# %%
inputs = Input(shape=(30, 14))
lstm_out = LSTM(50, return_sequences=True)(inputs)
attention = AdditiveAttention()([lstm_out, lstm_out])
context = Concatenate()([lstm_out, attention])
lstm_out2 = LSTM(50)(context)
outputs = Dense(96)(lstm_out2)
outputs = Dense(128)(outputs)
outputs = Dense(1)(outputs)


AdditiveAttention_lst_model = Model(inputs, outputs)
AdditiveAttention_lst_model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.RootMeanSquaredError()])


AdditiveAttention_lst_model.summary()
#tf.keras.utils.plot_model(AdditiveAttention_lst_model, "my_first_model_with_shape_info.png", show_shapes=True)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 30, 14)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_7 (LSTM)       │ (None, 30, 50)    │     13,000 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ additive_attention  │ (None, 30, 50)    │         50 │ lstm_7[0][0],     │
# │ (AdditiveAttention) │                   │            │ lstm_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 30, 100)   │          0 │ lstm_7[0][0],     │
# │ (Concatenate)       │                   │            │ additive_attenti… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_8 (LSTM)       │ (None, 50)        │     30,200 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 96)        │      4,896 │ lstm_8[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 128)       │     12,416 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 1)         │        129 │ dense_17[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 60,691 (237.07 KB)
#  Trainable params: 60,691 (237.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def evaluate(true_rul ,pred_rul, model):
  MAE = mean_absolute_error(true_rul, pred_rul)
  RMSE = np.sqrt(mean_squared_error(true_rul, pred_rul))
  r2 = r2_score(true_rul, pred_rul)
  diff = pred_rul - true_rul
  s_score = np.sum(np.where(diff < 0, np.exp(-diff/13)-1, np.exp(diff/10)-1))
  print("Testing : R-square = ",r2,'MAE = ',MAE,"RMSE = ", RMSE,"S-score = ", s_score)

# %%
batch_size = 32
epoch = 100

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.001)


model =  AdditiveAttention_lst_model

# %%
history_train_loss = []
history_val_loss = []

print("================ Attention-LSTM ================")
start_time = time.time()

model_history = model.fit(processed_train_data, processed_train_targets, epochs=epoch, batch_size=batch_size, validation_data = (processed_test_data, true_rul),
                  callbacks=[early_stopping, reduce_lr])

#model.save('Model_folder/Attention-LSTM_FD003.keras') # Save Model

rul_pred = model.predict(processed_test_data, verbose = 1).reshape(-1)
end_time = time.time()

print('Training : loss = ',model_history.history['loss'][-1])
print('Validation : loss = ',model_history.history['val_loss'][-1])
evaluate(true_rul, rul_pred, "Attention-LSTM")

history_train_loss.append(model_history.history['loss'])
history_val_loss.append(model_history.history['val_loss'])
print( 'Run Time :',int(end_time - start_time),'sec')
# Out:
# ================ Attention-LSTM ================
# Epoch 1/100
# I0000 00:00:1735848021.993283   81687 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 2325.2908 - mean_absolute_error: 37.3343 - root_mean_squared_error: 46.1886 - val_loss: 461.4533 - val_mean_absolute_error: 16.5472 - val_root_mean_squared_error: 21.4815 - learning_rate: 0.0010
# Epoch 2/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 303.5756 - mean_absolute_error: 12.5518 - root_mean_squared_error: 17.4167 - val_loss: 351.9406 - val_mean_absolute_error: 14.6024 - val_root_mean_squared_error: 18.7601 - learning_rate: 0.0010
# Epoch 3/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 254.0161 - mean_absolute_error: 11.4636 - root_mean_squared_error: 15.9333 - val_loss: 293.5293 - val_mean_absolute_error: 13.2209 - val_root_mean_squared_error: 17.1327 - learning_rate: 0.0010
# Epoch 4/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 212.7509 - mean_absolute_error: 10.3349 - root_mean_squared_error: 14.5841 - val_loss: 354.4700 - val_mean_absolute_error: 14.3775 - val_root_mean_squared_error: 18.8274 - learning_rate: 0.0010
# Epoch 5/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 202.0485 - mean_absolute_error: 9.9935 - root_mean_squared_error: 14.2136 - val_loss: 284.0051 - val_mean_absolute_error: 13.0480 - val_root_mean_squared_error: 16.8525 - learning_rate: 0.0010
# Epoch 6/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 190.6553 - mean_absolute_error: 9.7594 - root_mean_squared_error: 13.8061 - val_loss: 285.4404 - val_mean_absolute_error: 12.9798 - val_root_mean_squared_error: 16.8950 - learning_rate: 0.0010
# Epoch 7/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 184.9943 - mean_absolute_error: 9.4982 - root_mean_squared_error: 13.5990 - val_loss: 293.0068 - val_mean_absolute_error: 13.3505 - val_root_mean_squared_error: 17.1174 - learning_rate: 0.0010
# Epoch 8/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 175.6200 - mean_absolute_error: 9.2230 - root_mean_squared_error: 13.2481 - val_loss: 330.8399 - val_mean_absolute_error: 13.9745 - val_root_mean_squared_error: 18.1890 - learning_rate: 0.0010
# Epoch 9/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 177.4637 - mean_absolute_error: 9.3659 - root_mean_squared_error: 13.3192 - val_loss: 292.8913 - val_mean_absolute_error: 12.8377 - val_root_mean_squared_error: 17.1141 - learning_rate: 0.0010
# Epoch 10/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 166.3703 - mean_absolute_error: 8.9506 - root_mean_squared_error: 12.8971 - val_loss: 251.7339 - val_mean_absolute_error: 12.1195 - val_root_mean_squared_error: 15.8661 - learning_rate: 0.0010
# Epoch 11/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 158.6828 - mean_absolute_error: 8.6141 - root_mean_squared_error: 12.5946 - val_loss: 273.4581 - val_mean_absolute_error: 12.3305 - val_root_mean_squared_error: 16.5366 - learning_rate: 0.0010
# Epoch 12/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 153.8536 - mean_absolute_error: 8.5597 - root_mean_squared_error: 12.4023 - val_loss: 243.8337 - val_mean_absolute_error: 11.9037 - val_root_mean_squared_error: 15.6152 - learning_rate: 0.0010
# Epoch 13/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 152.1871 - mean_absolute_error: 8.4820 - root_mean_squared_error: 12.3340 - val_loss: 200.6438 - val_mean_absolute_error: 10.6605 - val_root_mean_squared_error: 14.1649 - learning_rate: 0.0010
# Epoch 14/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 145.1814 - mean_absolute_error: 8.2630 - root_mean_squared_error: 12.0475 - val_loss: 200.0263 - val_mean_absolute_error: 10.6812 - val_root_mean_squared_error: 14.1431 - learning_rate: 0.0010
# Epoch 15/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 141.2543 - mean_absolute_error: 8.1270 - root_mean_squared_error: 11.8840 - val_loss: 240.6636 - val_mean_absolute_error: 11.8097 - val_root_mean_squared_error: 15.5133 - learning_rate: 0.0010
# Epoch 16/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 125.4864 - mean_absolute_error: 7.5315 - root_mean_squared_error: 11.2003 - val_loss: 207.4877 - val_mean_absolute_error: 10.8153 - val_root_mean_squared_error: 14.4044 - learning_rate: 0.0010
# Epoch 17/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 132.5778 - mean_absolute_error: 7.7906 - root_mean_squared_error: 11.5133 - val_loss: 209.4342 - val_mean_absolute_error: 10.8426 - val_root_mean_squared_error: 14.4718 - learning_rate: 0.0010
# Epoch 18/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 127.9756 - mean_absolute_error: 7.6208 - root_mean_squared_error: 11.3111 - val_loss: 201.2220 - val_mean_absolute_error: 10.6655 - val_root_mean_squared_error: 14.1853 - learning_rate: 0.0010
# Epoch 19/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 130.3016 - mean_absolute_error: 7.6464 - root_mean_squared_error: 11.4108 - val_loss: 188.2573 - val_mean_absolute_error: 10.1626 - val_root_mean_squared_error: 13.7207 - learning_rate: 0.0010
# Epoch 20/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 121.6925 - mean_absolute_error: 7.4387 - root_mean_squared_error: 11.0305 - val_loss: 200.6382 - val_mean_absolute_error: 10.7718 - val_root_mean_squared_error: 14.1647 - learning_rate: 0.0010
# Epoch 21/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 124.2433 - mean_absolute_error: 7.4697 - root_mean_squared_error: 11.1434 - val_loss: 222.1602 - val_mean_absolute_error: 11.6767 - val_root_mean_squared_error: 14.9050 - learning_rate: 0.0010
# Epoch 22/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 125.5648 - mean_absolute_error: 7.5490 - root_mean_squared_error: 11.2038 - val_loss: 196.0268 - val_mean_absolute_error: 10.5131 - val_root_mean_squared_error: 14.0010 - learning_rate: 0.0010
# Epoch 23/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 116.4204 - mean_absolute_error: 7.2729 - root_mean_squared_error: 10.7880 - val_loss: 236.5106 - val_mean_absolute_error: 11.9609 - val_root_mean_squared_error: 15.3789 - learning_rate: 0.0010
# Epoch 24/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 116.6800 - mean_absolute_error: 7.2577 - root_mean_squared_error: 10.8008 - val_loss: 186.1835 - val_mean_absolute_error: 10.2107 - val_root_mean_squared_error: 13.6449 - learning_rate: 0.0010
# Epoch 25/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 119.5032 - mean_absolute_error: 7.3239 - root_mean_squared_error: 10.9299 - val_loss: 185.0305 - val_mean_absolute_error: 10.4333 - val_root_mean_squared_error: 13.6026 - learning_rate: 0.0010
# Epoch 26/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 114.3223 - mean_absolute_error: 7.0977 - root_mean_squared_error: 10.6901 - val_loss: 164.9060 - val_mean_absolute_error: 9.6357 - val_root_mean_squared_error: 12.8416 - learning_rate: 0.0010
# Epoch 27/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 115.8422 - mean_absolute_error: 7.2331 - root_mean_squared_error: 10.7603 - val_loss: 251.8750 - val_mean_absolute_error: 12.4284 - val_root_mean_squared_error: 15.8706 - learning_rate: 0.0010
# Epoch 28/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 113.3989 - mean_absolute_error: 7.1456 - root_mean_squared_error: 10.6478 - val_loss: 168.8268 - val_mean_absolute_error: 9.7866 - val_root_mean_squared_error: 12.9933 - learning_rate: 0.0010
# Epoch 29/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 111.0937 - mean_absolute_error: 6.9612 - root_mean_squared_error: 10.5390 - val_loss: 171.8170 - val_mean_absolute_error: 9.9341 - val_root_mean_squared_error: 13.1079 - learning_rate: 0.0010
# Epoch 30/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 112.9182 - mean_absolute_error: 7.1029 - root_mean_squared_error: 10.6255 - val_loss: 189.1577 - val_mean_absolute_error: 9.8831 - val_root_mean_squared_error: 13.7535 - learning_rate: 0.0010
# Epoch 31/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 112.4279 - mean_absolute_error: 7.0513 - root_mean_squared_error: 10.6013 - val_loss: 169.8255 - val_mean_absolute_error: 9.6669 - val_root_mean_squared_error: 13.0317 - learning_rate: 0.0010
# Epoch 32/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 113.8486 - mean_absolute_error: 7.1545 - root_mean_squared_error: 10.6670 - val_loss: 170.4666 - val_mean_absolute_error: 9.9474 - val_root_mean_squared_error: 13.0563 - learning_rate: 0.0010
# Epoch 33/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 108.8149 - mean_absolute_error: 6.9467 - root_mean_squared_error: 10.4306 - val_loss: 172.5419 - val_mean_absolute_error: 10.2355 - val_root_mean_squared_error: 13.1355 - learning_rate: 0.0010
# Epoch 34/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 110.1047 - mean_absolute_error: 7.0196 - root_mean_squared_error: 10.4915 - val_loss: 176.5304 - val_mean_absolute_error: 9.8804 - val_root_mean_squared_error: 13.2865 - learning_rate: 0.0010
# Epoch 35/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 112.1711 - mean_absolute_error: 7.0872 - root_mean_squared_error: 10.5898 - val_loss: 152.6284 - val_mean_absolute_error: 9.3098 - val_root_mean_squared_error: 12.3543 - learning_rate: 0.0010
# Epoch 36/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 105.1732 - mean_absolute_error: 6.7701 - root_mean_squared_error: 10.2511 - val_loss: 159.4229 - val_mean_absolute_error: 9.3395 - val_root_mean_squared_error: 12.6263 - learning_rate: 0.0010
# Epoch 37/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 106.0488 - mean_absolute_error: 6.7833 - root_mean_squared_error: 10.2959 - val_loss: 161.3469 - val_mean_absolute_error: 9.6788 - val_root_mean_squared_error: 12.7022 - learning_rate: 0.0010
# Epoch 38/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 103.4329 - mean_absolute_error: 6.6573 - root_mean_squared_error: 10.1666 - val_loss: 181.9845 - val_mean_absolute_error: 9.9910 - val_root_mean_squared_error: 13.4902 - learning_rate: 0.0010
# Epoch 39/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 105.6072 - mean_absolute_error: 6.8138 - root_mean_squared_error: 10.2756 - val_loss: 178.3217 - val_mean_absolute_error: 10.1934 - val_root_mean_squared_error: 13.3537 - learning_rate: 0.0010
# Epoch 40/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 103.0453 - mean_absolute_error: 6.6617 - root_mean_squared_error: 10.1504 - val_loss: 167.7051 - val_mean_absolute_error: 9.5834 - val_root_mean_squared_error: 12.9501 - learning_rate: 0.0010
# Epoch 41/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 106.9154 - mean_absolute_error: 6.7713 - root_mean_squared_error: 10.3276 - val_loss: 169.5661 - val_mean_absolute_error: 10.0172 - val_root_mean_squared_error: 13.0218 - learning_rate: 0.0010
# Epoch 42/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 104.8189 - mean_absolute_error: 6.7165 - root_mean_squared_error: 10.2367 - val_loss: 158.0524 - val_mean_absolute_error: 9.3890 - val_root_mean_squared_error: 12.5719 - learning_rate: 0.0010
# Epoch 43/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 102.7048 - mean_absolute_error: 6.6200 - root_mean_squared_error: 10.1337 - val_loss: 192.3053 - val_mean_absolute_error: 10.7003 - val_root_mean_squared_error: 13.8674 - learning_rate: 0.0010
# Epoch 44/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 102.2826 - mean_absolute_error: 6.5573 - root_mean_squared_error: 10.1124 - val_loss: 138.4419 - val_mean_absolute_error: 8.9527 - val_root_mean_squared_error: 11.7661 - learning_rate: 0.0010
# Epoch 45/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 100.9556 - mean_absolute_error: 6.5615 - root_mean_squared_error: 10.0459 - val_loss: 176.7990 - val_mean_absolute_error: 9.4404 - val_root_mean_squared_error: 13.2966 - learning_rate: 0.0010
# Epoch 46/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 100.8342 - mean_absolute_error: 6.5373 - root_mean_squared_error: 10.0391 - val_loss: 190.7632 - val_mean_absolute_error: 9.8611 - val_root_mean_squared_error: 13.8117 - learning_rate: 0.0010
# Epoch 47/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 98.9577 - mean_absolute_error: 6.5137 - root_mean_squared_error: 9.9458 - val_loss: 159.7340 - val_mean_absolute_error: 9.2985 - val_root_mean_squared_error: 12.6386 - learning_rate: 0.0010
# Epoch 48/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 100.3358 - mean_absolute_error: 6.5667 - root_mean_squared_error: 10.0164 - val_loss: 152.1587 - val_mean_absolute_error: 9.0164 - val_root_mean_squared_error: 12.3353 - learning_rate: 0.0010
# Epoch 49/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 98.0629 - mean_absolute_error: 6.5043 - root_mean_squared_error: 9.9017 - val_loss: 144.1515 - val_mean_absolute_error: 9.0048 - val_root_mean_squared_error: 12.0063 - learning_rate: 0.0010
# Epoch 50/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 95.2031 - mean_absolute_error: 6.2869 - root_mean_squared_error: 9.7511 - val_loss: 155.7489 - val_mean_absolute_error: 9.1770 - val_root_mean_squared_error: 12.4799 - learning_rate: 0.0010
# Epoch 51/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 93.7544 - mean_absolute_error: 6.3179 - root_mean_squared_error: 9.6804 - val_loss: 146.4593 - val_mean_absolute_error: 8.8869 - val_root_mean_squared_error: 12.1020 - learning_rate: 0.0010
# Epoch 52/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 95.6053 - mean_absolute_error: 6.3238 - root_mean_squared_error: 9.7766 - val_loss: 167.4052 - val_mean_absolute_error: 9.6292 - val_root_mean_squared_error: 12.9385 - learning_rate: 0.0010
# Epoch 53/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 94.7042 - mean_absolute_error: 6.2553 - root_mean_squared_error: 9.7289 - val_loss: 164.4146 - val_mean_absolute_error: 9.4903 - val_root_mean_squared_error: 12.8224 - learning_rate: 0.0010
# Epoch 54/100
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 96.5388 - mean_absolute_error: 6.4492 - root_mean_squared_error: 9.8246 - val_loss: 154.7467 - val_mean_absolute_error: 9.2515 - val_root_mean_squared_error: 12.4397 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Training : loss =  93.77363586425781
# Validation : loss =  154.7467041015625
# Testing : R-square =  0.9192097783088684 MAE =  8.952656745910645 RMSE =  11.766134668990837 S-score =  212.14805225294356
# Run Time : 198 sec

# %% [markdown]
# ## Load Models

# %%
model =load_model('Model_folder/Attention-LSTM_FD003.keras')

# %%
print("================ Attention-LSTM ================")
rul_pred = model.predict(processed_test_data, verbose = 1).reshape(-1)
evaluate(true_rul, rul_pred, "Attention-LSTM")
# Out:
# ================ Attention-LSTM ================
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Testing : R-square =  0.9192097783088684 MAE =  8.952656745910645 RMSE =  11.766134668990837 S-score =  212.14805225294356
# I0000 00:00:1735921151.755537    9750 cuda_dnn.cc:529] Loaded cuDNN version 90300

# %% [markdown]
# ## Plot real data and the predicted one to make some comparison

# %%
def plot_predActual(y_test, y_predictions,model_name):
  #plt.style.use('seaborn-white')
  plt.rcParams['figure.figsize']=20,5
  fig,ax = plt.subplots()
  plt.title( model_name +' prediction result',fontsize =16)
  plt.ylabel('RUL',fontsize =16)
  plt.xlabel('Test Engine Units',fontsize =16)
  g = sns.lineplot(x = np.arange(0,len(train_data[0].unique())),y = y_test,color='lightseagreen',label = 'actual',ax=ax)
  f = sns.lineplot(x = np.arange(0,len(train_data[0].unique())),y = y_predictions,color='salmon',label = 'predictions',ax=ax)
  ax.grid(True)
  ax.legend()
  plt.show()

# %%
rul_pred = model.predict(processed_test_data,verbose=0).reshape(-1)
preds_for_each_engine = np.split(rul_pred, np.cumsum(num_test_windows_list)[:-1])
mean_pred_for_each_engine = [np.average(ruls_for_each_engine, weights = np.repeat(1/num_windows, num_windows))
                            for ruls_for_each_engine, num_windows in zip(preds_for_each_engine, num_test_windows_list)]
y_true = true_rul.reshape(1,len(true_rul))[0]
plot_predActual(y_true, mean_pred_for_each_engine,"Attention-LSTM")

# %%
def Prdection_engine_id(eng_id,model):
    temp_test_data = test_data[test_data[0] == eng_id].drop(columns = [0]).values
    num_wind=len(temp_test_data)
    # Verify if data of given window length can be extracted from test data
    if (len(temp_test_data) < num_wind):
         print("Test engine {} doesn't have enough data for window_length of {}".format(i, window_length))
         raise AssertionError("Window length is larger than number of data points for some engines. "
                             "Try decreasing window length.")


    # Prepare test data
    test_data_for_an_engine, num_windows = process_test_data(temp_test_data, window_length = window_length, shift = shift,
                                                             num_test_windows = num_wind)

    rul_pred = model.predict(test_data_for_an_engine, verbose = 1).reshape(-1)

    rul = []
    for i in range(num_windows,0,-1):
        if (i<125):
           rul.append(i)
        else:
           rul.append(125)
   
    plt.figure(figsize = (8, 5))
    plt.plot(rul)
    plt.plot(rul_pred)
    plt.ylabel('RUL')
    plt.xlabel('Cycle')
    plt.legend(['actual', 'predictions'])
    plt.title("Engine #"+str(eng_id))
    plt.show()

# %%
Prdection_engine_id(40,model)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
